# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Colab_me
# Out:
# /content/drive/MyDrive/Colab_me

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
import os
import warnings
import joblib

warnings.filterwarnings("ignore")
sns.set_style()
plt.style.use('seaborn')

# %%
df_ST = pd.read_csv('/content/drive/MyDrive/DS105/dataset/dataset_predict/df_ST.csv')
df_CM = pd.read_csv('/content/drive/MyDrive/DS105/dataset/dataset_predict/df_CM.csv')
df_CB = pd.read_csv('/content/drive/MyDrive/DS105/dataset/dataset_predict/df_CB.csv')
df_GK = pd.read_csv('/content/drive/MyDrive/DS105/dataset/dataset_predict/df_GK.csv')

# %% [markdown]
# ## Predict function

# %%
# model_name, kargs thuộc tính ứng với từng nhóm vị trí
def recommend_ST (model_name, **kargs):
  # load model
  if model_name == 'kmeans':
    model = joblib.load('/content/drive/MyDrive/DS105/source/model/model_ST_K-means-4.sav')
  elif model_name == 'hierarchical': 
    model = joblib.load('/content/drive/MyDrive/DS105/source/model/model_ST_Hierarchical-5.sav')
    model_svm = joblib.load('/content/drive/MyDrive/DS105/source/model/model_SVM_ST.sav')

  # Khởi tạo (Nếu không có tham số thì recommend cầu thủ xịn nhất)
  StandingTackle = 72.0
  ShotPower = 94.0
  Jumping = 95.0
  Stamina = 92.0
  Strength = 97.0
  SprintSpeed = 97.0
  Agility = 96.0
  Reactions = 81.0
  Balance = 95.0 
  Dribbling = 86.0
  Curve = 94.0
  FKAccuracy = 94.0
  LongPassing = 91.0
  Crossing = 88.0
  Volleys = 90.0

  # Lấy giá trị 
  for id in kargs:
    if id == 'StandingTackle': 
        StandingTackle = kargs.get('StandingTackle')
    if id == 'ShotPower': 
        ShotPower = kargs.get('ShotPower')
    if id == 'Jumping': 
        Jumping = kargs.get('Jumping')
    if id == 'Stamina': 
        Stamina = kargs.get('Stamina')
    if id == 'Strength': 
        Strength = kargs.get('Strength')
    if id == 'SprintSpeed': 
        SprintSpeed = kargs.get('SprintSpeed')
    if id == 'Agility': 
        Agility = kargs.get('Agility')
    if id == 'Reactions': 
        Reactions = kargs.get('Reactions')
    if id == 'Balance': 
        Balance = kargs.get('Balance')
    if id == 'Dribbling': 
        Dribbling = kargs.get('Dribbling')
    if id == 'Curve': 
        Curve = kargs.get('Curve')
    if id == 'FKAccuracy': 
        FKAccuracy = kargs.get('FKAccuracy')
    if id == 'LongPassing': 
        LongPassing = kargs.get('LongPassing')
    if id == 'Crossing': 
        Crossing = kargs.get('Crossing')
    if id == 'Volleys': 
        Volleys = kargs.get('Volleys')

  # Chuyển các giá trị về dạng array phù hợp với input đầu vào
  array_value = np.array([[StandingTackle, ShotPower,	Jumping, Stamina, Strength, SprintSpeed, Agility, Reactions, Balance, Dribbling, Curve, FKAccuracy, LongPassing, Crossing, Volleys]])
  if model_name == 'kmeans': 
    pred = model.predict(array_value)
    return df_ST[df_ST['cluster_KMeans']==pred[0]].sample(10)
  elif model_name == 'hierarchical': 
    pred = model_svm.predict(array_value)
    return df_ST[df_ST['cluster_Hierarchical']==pred[0]].sample(10)

# %%
def recommend_CM (model_name, **kargs):
  # load model
  if model_name == 'kmeans':
    model = joblib.load('/content/drive/MyDrive/DS105/source/model/model_CM_K-means-4.sav')
  elif model_name == 'hierarchical': 
    model = joblib.load('/content/drive/MyDrive/DS105/source/model/model_CM_Hierarchical-6.sav')
    model_svm = joblib.load('/content/drive/MyDrive/DS105/source/model/model_SVM_CM.sav')

  # Khởi tạo (Nếu không có tham số thì recommend cầu thủ xịn nhất)
  SlidingTackle = 87.0
  Aggression = 95.0
  Penalties = 92.0
  SprintSpeed = 96.0
  Agility = 95.0
  Reactions = 81.0
  Balance = 96.0
  Dribbling = 86.0
  FKAccuracy = 92.0 
  LongPassing = 93.0
  Crossing = 94.0
  Finishing = 88.0
  Volleys = 90.0

  # Lấy giá trị 
  for id in kargs:
    if id == 'SlidingTackle': 
        SlidingTackle = kargs.get('SlidingTackle')
    if id == 'Aggression': 
        Aggression = kargs.get('Aggression')
    if id == 'Penalties': 
        Penalties = kargs.get('Penalties')
    if id == 'SprintSpeed': 
        SprintSpeed = kargs.get('SprintSpeed')
    if id == 'Agility': 
        Agility = kargs.get('Agility')
    if id == 'Reactions': 
        Reactions = kargs.get('Reactions')
    if id == 'Balance': 
        Balance = kargs.get('Balance')
    if id == 'Dribbling': 
        Dribbling = kargs.get('Dribbling')
    if id == 'FKAccuracy': 
        FKAccuracy = kargs.get('FKAccuracy')
    if id == 'LongPassing': 
        LongPassing = kargs.get('LongPassing')
    if id == 'Crossing': 
        Crossing = kargs.get('Crossing')
    if id == 'Finishing': 
        Finishing = kargs.get('Finishing')
    if id == 'Volleys': 
        Volleys = kargs.get('Volleys')

  # Chuyển các giá trị về dạng array phù hợp với input đầu vào
  array_value = np.array([[	SlidingTackle,	Aggression,	Penalties,	SprintSpeed,	Agility,	Reactions,	Balance	,Dribbling,	FKAccuracy,	LongPassing,	Crossing,	Finishing	,Volleys]])
  
  if model_name == 'kmeans': 
    pred = model.predict(array_value)
    return df_CM[df_CM['cluster_KMeans']==pred[0]].sample(10)
  elif model_name == 'hierarchical': 
    pred = model_svm.predict(array_value)
    return df_CM[df_CM['cluster_Hierarchical']==pred[0]].sample(10)

# %%
def recommend_CB (model_name, **kargs):
  # load model
  if model_name == 'kmeans':
    model = joblib.load('/content/drive/MyDrive/DS105/source/model/model_CB_K-means-3.sav')
  elif model_name == 'hierarchical': 
    model = joblib.load('/content/drive/MyDrive/DS105/source/model/model_CB_Hierarchical-4.sav')
    model_svm = joblib.load('/content/drive/MyDrive/DS105/source/model/model_SVM_CB.sav')

  # Khởi tạo (Nếu không có tham số thì recommend cầu thủ xịn nhất)
  StandingTackle = 92.0
  Aggression = 95.0
  Positioning = 86.0
  Vision = 87.0
  Penalties = 92.0
  Composure = 84.0

  # Lấy giá trị 
  for id in kargs:
    if id == 'StandingTackle': 
        StandingTackle = kargs.get('StandingTackle')
    if id == 'Aggression': 
        Aggression = kargs.get('Aggression')
    if id == 'Positioning': 
        Positioning = kargs.get('Positioning')
    if id == 'Vision': 
        Vision = kargs.get('Vision')
    if id == 'Penalties': 
        Penalties = kargs.get('Penalties')
    if id == 'Composure': 
        Composure = kargs.get('Composure')

  # Chuyển các giá trị về dạng array phù hợp với input đầu vào
  array_value = np.array([[StandingTackle,	Aggression,	Positioning,	Vision,	Penalties, Composure]])
  
  if model_name == 'kmeans': 
    pred = model.predict(array_value)
    return df_CB[df_CB['cluster_KMeans']==pred[0]].sample(10)
  elif model_name == 'hierarchical': 
    pred = model_svm.predict(array_value)
    return df_CB[df_CB['cluster_Hierarchical']==pred[0]].sample(10)

# %%
def recommend_GK (model_name, **kargs):
  # load model
  if model_name == 'kmeans':
    model = joblib.load('/content/drive/MyDrive/DS105/source/model/model_GK_K-means-3.sav')
  elif model_name == 'hierarchical': 
    model = joblib.load('/content/drive/MyDrive/DS105/source/model/model_GK_Hierarchical-2.sav')
    model_svm = joblib.load('/content/drive/MyDrive/DS105/source/model/model_SVM_GK.sav')

  # Khởi tạo (Nếu không có tham số thì recommend cầu thủ xịn nhất)
  GKReflexes = 90.0
  ShotPower = 70.0
  Jumping = 84.0
  Stamina = 45.0
  Strength = 85.0
  LongShots = 45.0

  # Lấy giá trị 
  for id in kargs:
    if id == 'GKReflexes': 
        GKReflexes = kargs.get('GKReflexes')
    if id == 'ShotPower': 
        ShotPower = kargs.get('ShotPower')
    if id == 'Jumping': 
        Jumping = kargs.get('Jumping')
    if id == 'Stamina': 
        Stamina = kargs.get('Stamina')
    if id == 'Strength': 
        Strength = kargs.get('Strength')
    if id == 'LongShots': 
        LongShots = kargs.get('LongShots')

  # Chuyển các giá trị về dạng array phù hợp với input đầu vào
  array_value = np.array([[GKReflexes,	ShotPower,	Jumping,	Stamina,	Strength,	LongShots]])
  
  if model_name == 'kmeans': 
    pred = model.predict(array_value)
    return df_GK[df_GK['cluster_KMeans']==pred[0]].sample(10)
  elif model_name == 'hierarchical': 
    pred = model_svm.predict(array_value)
    return df_GK[df_GK['cluster_Hierarchical']==pred[0]].sample(10)

# %% [markdown]
# # Test function

# %% [markdown]
# # Các khoảng giá trị của features

# %% [markdown]
# ST

# %%
# 14
print(('StandingTackle',df_ST['StandingTackle'].min(), df_ST['StandingTackle'].max()))
print(('ShotPower',df_ST['ShotPower'].min(), df_ST['ShotPower'].max()))
print(('Jumping',df_ST['Jumping'].min(), df_ST['Jumping'].max()))
print(('Stamina',df_ST['Stamina'].min(), df_ST['Stamina'].max()))
print(('Strength',df_ST['Strength'].min(), df_ST['Strength'].max()))
print(('SprintSpeed',df_ST['SprintSpeed'].min(), df_ST['SprintSpeed'].max()))
print(('Agility',df_ST['Agility'].min(), df_ST['Agility'].max()))
print(('Reactions',df_ST['Reactions'].min(), df_ST['Reactions'].max()))
print(('Balance',df_ST['Balance'].min(), df_ST['Balance'].max()))
print(('Dribbling',df_ST['Dribbling'].min(), df_ST['Dribbling'].max()))
print(('Curve',df_ST['Curve'].min(), df_ST['Curve'].max()))
print(('FKAccuracy',df_ST['FKAccuracy'].min(), df_ST['FKAccuracy'].max()))
print(('LongPassing',df_ST['LongPassing'].min(), df_ST['LongPassing'].max()))
print(('Crossing',df_ST['Crossing'].min(), df_ST['Crossing'].max()))
print(('Volleys',df_ST['Volleys'].min(), df_ST['Volleys'].max()))
# Out:
# ('StandingTackle', 10.0, 72.0)
# ('ShotPower', 38.0, 94.0)
# ('Jumping', 33.0, 95.0)
# ('Stamina', 30.0, 92.0)
# ('Strength', 34.0, 97.0)
# ('SprintSpeed', 32.0, 97.0)
# ('Agility', 30.0, 96.0)
# ('Reactions', 45.0, 81.0)
# ('Balance', 32.0, 95.0)
# ('Dribbling', 40.0, 86.0)
# ('Curve', 21.0, 94.0)
# ('FKAccuracy', 21.0, 94.0)
# ('LongPassing', 19.0, 91.0)
# ('Crossing', 20.0, 88.0)
# ('Volleys', 30.0, 90.0)

# %% [markdown]
# CM

# %%
# 13
print(('SlidingTackle',df_CM['SlidingTackle'].min(), df_CM['SlidingTackle'].max()))
print(('Aggression',df_CM['Aggression'].min(), df_CM['Aggression'].max()))
print(('Penalties',df_CM['Penalties'].min(), df_CM['Penalties'].max()))
print(('SprintSpeed',df_CM['SprintSpeed'].min(), df_CM['SprintSpeed'].max()))
print(('Agility',df_CM['Agility'].min(), df_CM['Agility'].max()))
print(('Reactions',df_CM['Reactions'].min(), df_CM['Reactions'].max()))
print(('Balance',df_CM['Balance'].min(), df_CM['Balance'].max()))
print(('Dribbling',df_CM['Dribbling'].min(), df_CM['Dribbling'].max()))
print(('FKAccuracy',df_CM['FKAccuracy'].min(), df_CM['FKAccuracy'].max()))
print(('LongPassing',df_CM['LongPassing'].min(), df_CM['LongPassing'].max()))
print(('Crossing',df_CM['Crossing'].min(), df_CM['Crossing'].max()))
print(('Finishing',df_CM['Finishing'].min(), df_CM['Finishing'].max()))
print(('Volleys',df_CM['Volleys'].min(), df_CM['Volleys'].max()))
# Out:
# ('SlidingTackle', 10.0, 87.0)
# ('Aggression', 20.0, 95.0)
# ('Penalties', 20.0, 92.0)
# ('SprintSpeed', 32.0, 96.0)
# ('Agility', 30.0, 95.0)
# ('Reactions', 45.0, 81.0)
# ('Balance', 32.0, 96.0)
# ('Dribbling', 35.0, 86.0)
# ('FKAccuracy', 20.0, 92.0)
# ('LongPassing', 26.0, 93.0)
# ('Crossing', 22.0, 94.0)
# ('Finishing', 21.0, 88.0)
# ('Volleys', 17.0, 90.0)

# %% [markdown]
# CB

# %%
# 6
print(('StandingTackle',df_CB['StandingTackle'].min(), df_CB['StandingTackle'].max()))
print(('Aggression',df_CB['Aggression'].min(), df_CB['Aggression'].max()))
print(('Positioning',df_CB['Positioning'].min(), df_CB['Positioning'].max()))
print(('Vision',df_CB['Vision'].min(), df_CB['Vision'].max()))
print(('Penalties',df_CB['Penalties'].min(), df_CB['Penalties'].max()))
print(('Composure',df_CB['Composure'].min(), df_CB['Composure'].max()))
# Out:
# ('StandingTackle', 43.0, 92.0)
# ('Aggression', 28.0, 95.0)
# ('Positioning', 12.0, 86.0)
# ('Vision', 25.0, 87.0)
# ('Penalties', 13.0, 92.0)
# ('Composure', 35.0, 84.0)

# %% [markdown]
# GK

# %%
# 6
print(('GKReflexes',df_GK['GKReflexes'].min(), df_GK['GKReflexes'].max()))
print(('ShotPower',df_GK['ShotPower'].min(), df_GK['ShotPower'].max()))
print(('Jumping',df_GK['Jumping'].min(), df_GK['Jumping'].max()))
print(('Stamina',df_GK['Stamina'].min(), df_GK['Stamina'].max()))
print(('Strength',df_GK['Strength'].min(), df_GK['Strength'].max()))
print(('LongShots',df_GK['LongShots'].min(), df_GK['LongShots'].max()))
# Out:
# ('GKReflexes', 16.0, 90.0)
# ('ShotPower', 29.0, 70.0)
# ('Jumping', 22.0, 84.0)
# ('Stamina', 13.0, 45.0)
# ('Strength', 24.0, 85.0)
# ('LongShots', 4.0, 45.0)

# %%
position = "ST"
algor = 'kmeans'
if position == "ST": 
  result = recommend_ST('kmeans', StandingTackle = 20)
result
# Out:
#           ID            Name  Age Nationality  Overall  Potential  \
# 1264  194925        L. Moult   29     England       66         66
# 829   192663         F. Klos   33     Germany       73         73
# 1415  190664  21 J. Schieber   31     Germany       68         68
# 1625  241850      M. Retegui   22   Argentina       69         77
# 1322  171982    21 C. Andrew   33     England       60         60
# 1698  165185    20 C. Davies   33       Wales       62         62
# 2145  241984        C. Burke   29     Jamaica       68         68
# 1332  163340    21 D. Graham   34     England       65         65
# 2098  263791      Ricardinho   20      Brazil       65         75
# 2372  264346      D. Lemajić   27      Serbia       64         64
#
#                         Club  Value  Wage  Special  ... GKKicking  \
# 1264           Burton Albion  €850K   €3K     1687  ...      10.0
# 829    DSC Arminia Bielefeld  €1.9M  €22K     1763  ...       7.0
# ...

# %%
position = "ST"
if position == "ST": 
  result = recommend_ST('hierarchical')
result
# Out:
#          ID             Name  Age  Nationality  Overall  Potential  \
# 123  216700          M. Meza   28    Argentina       76         76
# 130  153177     21 M. Zárate   33    Argentina       75         75
# 57   213013    F. Acheampong   27        Ghana       77         77
# 52   220883         R. Borré   25     Colombia       78         81
# 161  202858      F. Castillo   29     Colombia       75         75
# 111  231447         D. Malen   22  Netherlands       80         85
# 339  184176         G. Bruno   29      Belgium       73         73
# 251  210617  Samu Castillejo   26        Spain       77         77
# 94   224510           W. Bou   27    Argentina       75         75
# 27   184200    M. Arnautović   32      Austria       81         81
#
#                     Club   Value  Wage  Special  ... GKKicking  GKPositioning  \
# 123        CF Monterrey    €7.5M  €49K     1975  ...      15.0           12.0
# ...

# %%
position = "CM"
if position == "CM": 
  result = recommend_CM('kmeans')
result
# Out:
#           ID             Name  Age    Nationality  Overall  Potential  \
# 2392  244565       E. Erhahon   20       Scotland       66         76
# 4322  239835  V. Mpindi Ekani   24       Cameroon       66         71
# 906   210374         J. Vigón   29         Mexico       73         73
# 1302  222844           Walace   26         Brazil       73         75
# 2114  237109      O. Karavaev   29        Ukraine       73         73
# 4058  246310        C. Cappis   21  United States       63         74
# 3901  237721   A. Al Khaibari   24   Saudi Arabia       66         73
# 2434  246255       D. Kulikov   23         Russia       70         79
# 2891  239498       B. Henning   26        Germany       66         68
# 2747  211671     J. Radošević   27        Croatia       68         70
#
#                         Club  Value  Wage  Special  ... GKKicking  \
# 2392              St. Mirren  €1.9M   €2K     1806  ...      13.0
# ...

# %%
position = "CM"
if position == "CM": 
  result = recommend_CM('hierarchical')
result
# Out:
#           ID           Name  Age          Nationality  Overall  Potential  \
# 3668  225053        L. Rose   24            Australia       63         72
# 1447  222405    L. Kinsella   25  Republic of Ireland       64         67
# 3136  260158      T. Lacoux   19               France       67         77
# 4689  263155    B. Klefisch   18              Germany       58         75
# 1449  224336   T. Romanczuk   29               Poland       69         69
# 2057  241931      F. Moyano   23            Argentina       69         74
# 1974  188601       A. Coeff   29               France       68         69
# 2905  232928  Y. Matsushita   27                Japan       65         67
# 3704  258289      J. Sforza   19            Argentina       65         82
# 2204  244895       A. Yusuf   20              Nigeria       70         83
#
#                           Club  Value  Wage  Special  ... GKKicking  \
# 3668              Macarthur FC    €1M  €900     1706  ...       7.0
# ...

# %%
position = "CB"
if position == "CB": 
  result = recommend_CB('kmeans', StandingTackle =91,	Aggression =92,	Positioning = 82,	Vision = 83,	Penalties = 92, Composure = 84) # 
result
# Out:
#           ID           Name  Age Nationality  Overall  Potential  \
# 1743  238636  R. Preißinger   24     Germany       64         69
# 1099  254258  Nilton Varela   20    Portugal       68         77
# 1560  244950   J. Rodríguez   27   Argentina       73         74
# 1228  213537     20 B. Sarr   28     Senegal       71         71
# 1163  224891   Rafael Ramos   26    Portugal       70         73
# 391   235565       D. Bronn   26     Tunisia       75         78
# 1358  229605    C. Connolly   23     England       66         71
# 2707  241031      F. Garcés   21   Argentina       72         79
# 302   230189   Silas Almeim   29      Brazil       76         76
# 1696  166841       N. Adams   34       Wales       64         64
#
#                      Club  Value  Wage  Special  ... GKKicking  GKPositioning  \
# 1743     FC Ingolstadt 04  €800K   €4K     1726  ...      11.0            9.0
# 1099       Belenenses SAD  €2.5M   €2K     1803  ...      11.0           10.0
# ...

# %%
position = "CB"
if position == "CB": 
  result = recommend_CB('hierarchical')
result
# Out:
#           ID         Name  Age     Nationality  Overall  Potential  \
# 234   205364     F. Novák   31  Czech Republic       74         74
# 714   247150      A. Vigo   22       Argentina       73         81
# 301   202335      E. Dier   27         England       79         80
# 1671  224447     G. Jones   25           Wales       65         68
# 1918  229401  21 N. Mason   23         England       65         71
# 228   210455        Jonny   27           Spain       80         81
# 2279  212736  B. Kwiecień   27          Poland       64         67
# 290   230381   Kaimo Lima   25          Brazil       74         74
# 1303  172685  José Crespo   34           Spain       72         72
# 260   212218   A. Laporte   27           Spain       82         86
#
#                          Club   Value   Wage  Special  ... GKKicking  \
# 234             Fenerbahçe SK   €3.1M   €35K     1985  ...      14.0
# 714               River Plate   €6.5M   €11K     1867  ...      14.0
# ...

# %%
position = "GK"
if position == "GK": 
  result = recommend_GK('kmeans')
result
# Out:
#           ID              Name  Age          Nationality  Overall  Potential  \
# 2289  140420         B. Murphy   38  Republic of Ireland       61         61
# 2509  245359         C. Moreno   23               Mexico       59         68
# 1806  191655     Kim Seung Gyu   30       Korea Republic       69         69
# 1892  191628  21 L. Chichizola   30            Argentina       71         71
# 1582  232229         J. Bijlow   23          Netherlands       78         86
# 2481  236867           L. Dias   22               France       63         71
# 2111  146637   21 Dani Giménez   36                Spain       69         69
# 2095  250804          J. Walsh   19              England       55         72
# 1502  223573             Munir   32              Morocco       73         73
# 2565  251298          O. Hanin   23               Israel       58         65
#
#                      Club  Value  Wage  Special  ... GKKicking  GKPositioning  \
# ...

# %%
position = "GK"
if position == "GK": 
  result = recommend_GK('hierarchical')
result
# Out:
#           ID            Name  Age       Nationality  Overall  Potential  \
# 1860  192922      O. Jiménez   32            Mexico       73         73
# 2004  236758  O. Christensen   22           Denmark       70         78
# 1746  210923     M. Al Owais   29      Saudi Arabia       70         70
# 1777  221531       M. Maroši   27          Slovakia       67         70
# 2485  255236       M. Bakker   20       Netherlands       62         74
# 1403  199005         M. Ryan   29         Australia       77         79
# 2078  200466       V. Eicher   30           Germany       67         67
# 2124  226423     N. Gartside   23  Northern Ireland       58         68
# 1436  164853     A. Federici   36         Australia       70         70
# 1835  214373        A. Silva   37          Paraguay       71         71
#
#                        Club  Value  Wage  Special  ... GKKicking  \
# 1860           Club América  €1.5M  €26K     1153  ...      68.0
# ...
